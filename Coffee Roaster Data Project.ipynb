# %% [markdown]
# # Coffee Availability By Roaster - Web Scraping Project
# ## Using BeautifulSoup to gather information about coffees for sale from select roasters
#
# The goal of this project is to create a DataFrame with information compiled from selected Coffee Roaster websites in the U.S., with the goal of being able to compare and contrast the available options.
#
# Once the following info is in a pandas DataFrame, it will be possible to search and filter coffees based on preferred origin, price, etc.
#
#  - Information I hope to include:
#      + Roaster Name
#      + Coffee Name
#      + Country/Countries of Origin
#      + Description
#      + Tasting Notes
#      + Variety
#      + Process
#      + Size Options
#      + Avg Price Per Pound or Ounce

# %% [markdown]
# First, import the necessary libraries:

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import csv

# %% [markdown]
# A list of a few coffee roasters to begin:

# %%
onyx_url = 'https://onyxcoffeelab.com/collections/coffee'
equator_url = 'https://www.equatorcoffees.com/collections/coffees'
ruby_url = 'https://rubycoffeeroasters.com/collections/coffee'

# %% [markdown]
# This first function compiles a list of urls from each of the above websites; each url is one type of coffee.

# %%
def gather_coffee_links(url):
    r= requests.get(url)
    soup = BeautifulSoup(r.content, 'html.parser')
    coffee_links = soup.find_all('a')
    
    links = []
    for link in coffee_links:
        links.append(url+link["href"])

    coffee_link_list = []
    for link in links:
        if '/product' in link:
            coffee_link_list.append(link)

    return coffee_link_list

# %% [markdown]
# First, I want to gather information from Onyx Coffee Labs in Arkansas.

# %%
onyx_links = gather_coffee_links(onyx_url)

# %% [markdown]
# With a list of pages that include the information about each coffee, I can begin to extract the desired data. The function below scrapes a page for coffee attributes:

# %%
def get_coffee_attrs(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')
    coffee_data = {}
    try:
        name = soup.find('h1').text.strip()
    except:
        name = None
    try:
        coffee_description = soup.find('div', {'class':'main-blurb'}).getText().strip()
    except:
        coffee_description = None
    for div in soup.find_all('div', {'class':'a-feature'}):
        try:
            label = div.find('div', {'class':'label'})
            label_value = div.find('div', {'class':'value'})
            coffee_data[label.text]=label_value.text
        except:
            label = None
            label_value = None
    coffee_data.update({'Name':name, 'Description':coffee_description})
    return coffee_data

# %% [markdown]
# At the moment, I'm having difficulty extracting the price. As I experiment, I have separated sizes and prices to a different function seen below:

# %%
def get_size_and_price():
    r= requests.get('https://onyxcoffeelab.com/products/southern-weather?variant=31862699917410')
    soup = BeautifulSoup(r.text, 'html.parser')
    coffee_data = {}
    try:
        size = soup.find('div', {'class':'size-select option-type'}).text.strip()
        sizes = size.split('\n')
    except:
        size = None
    try:
        price = soup.select('div.price.variant-price')
    except: 
        price = None
    coffee_data.update({'Sizes Available' : sizes, 'Prices': price})
    print(coffee_data)

# %%
get_size_and_price()
# Out:
# {'Sizes Available': ['4oz', '10oz', '2lbs', '5lbs'], 'Prices': [<div class="price variant-price">
#
#                     $-.-
#
#                 </div>]}

# %% [markdown]
# As you can see above, the price is shown as empty. On the website this is (I think?) a flexbox, and the price changes when you select different sizes. Therefore, when I try find or find_all I am given no values/ an empty list.

# %% [markdown]
# Moving forward with what does work: we can collect coffee attribute data from all the Onyx coffee links:

# %%
coffee_data = []
for link in onyx_links:
    coffee_data.append(get_coffee_attrs(link))

# %% [markdown]
# This data is now converted into a pandas DataFrame for easier manipulation:

# %%
df_coffee_info = pd.DataFrame(coffee_data)
df_coffee_info
# Out:
#                        Variety:  \
# 0    Wazuka (Uji), Kyoto, Japan
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
# 6            Colombia, Ethiopia
# 7                           NaN
# 8            Colombia, Ethiopia
# 9                           NaN
# 10              Catuai, Caturra
# 11                         Java
# 12                        Gesha
# 13                  Red Bourbon
# 14               SL28, Ruiru 11
# 15         SL28, SL34, Ruiru 11
# 16                       Typica
# 17                 Pink Bourbon
# 18                     Heirloom
# 19                     Heirloom
# 20                 Pink Bourbon
# 21  Caturra, Castillo, Colombia
# 22  Caturra, Castillo, Colombia
# 23   Bourbon, Caturra, Castillo
# 24                          NaN
# 25              Catuai, Caturra
# 26            Ethiopia Heirloom
# 27                        Gesha
# 28                  Red Bourbon
# 29                    Parainema
# 30                     Heirloom
# 31                  Red Bourbon
# 32  Caturra, Castillo, Colombia
# 33                    Guatemala
#
#                                              Process:  \
# 0   Shaded 21 days, Processed to tencha, Stone milled
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                              Washed
# 5                                              Washed
# 6                                     Washed, Natural
# 7                                     Natural, Washed
# 8                            Washed, Raised-Bed Dreid
# 9                                 Washed, Patio Dried
# 10                                 Honey, Patio Dried
# 11          Koji Inoculated Natural, Raised Bed Dried
# 12                           Washed, Raised-Bed Dried
# 13                          Natural, Raised-Bed Dried
# 14                           Washed, Raised-Bed Dried
# 15                           Washed, Raised-Bed Dried
# 16                           Washed, Raised-Bed Dried
# 17                           Washed, Raised-Bed Dried
# 18                          Natural, Raised-Bed Dried
# 19                           Washed, Raised-Bed Dried
# 20                           Washed, Raised Bed Dried
# 21                    Lactic Washed, Raised Bed Dried
# 22                    Lactic Washed, Raised Bed Dried
# 23                           Washed, Raised Bed Dried
# 24           Washed Swiss-Water Decaf, Honey EA Decaf
# 25                          Natural, Raised-Bed Dried
# 26                          Natural, Raised-Bed Dried
# 27                 Washed & Natural, Raised-Bed Dried
# 28                          Natural, Raised-Bed Dried
# 29                          Natural, Raised Bed Dried
# 30                           Washed, Raised Bed Dried
# 31                           Washed, Raised-Bed Dried
# 32                          Washed, EA Decaffeination
# 33                           Washed, Raised-Bed Dried
#
#                                                  Cup: Caffeine:  \
# 0   Almond, Pomelo, White Sugar, Brisk Freshness, ...        mg
# 1                                                 NaN       NaN
# 2                                                 NaN       NaN
# 3                                                 NaN       NaN
# 4   Milk Chocolate, Plum, Candied Walnuts, Juicy &...       NaN
# 5   Berries, Stone Fruit, Earl Grey, Honeysuckle, ...       NaN
# 6   Dark Chocolate, Molasses, Red Wine, Dried Berr...       NaN
# 7           Mixed Berries, Sweet Tea, Raw Honey, Plum       NaN
# 8            Brown Sugar, Cocoa, Silky, Floral, Peach       NaN
# 9      Cocoa, Dates, Brown Sugar, Stone Fruit, Creamy       NaN
# 10           Apple Cider, Cherry, Cacao Nib, Hibiscus       NaN
# 11          Raspberry, Watermelon Candy, Winey, Mango       NaN
# 12            Lemon, Black Tea, Orange Blossom, Honey       NaN
# 13  Dried Cherry, Milk Chocolate, Nectarine, Black...       NaN
# 14           Ripe Peach, Raw Sugar, Grapefruit, Round       NaN
# 15  Ripe Nectarine, Cane Sugar, Grapefruit Oil, Hi...       NaN
# 16                          Almond, Lime, Clove, Pear       NaN
# 17              Plum, Black Tea, Blood Orange, Cherry       NaN
# 18              Plum, Vanilla Pod, Baked Apple, Round       NaN
# 19              Melon, Jasmine, Orange Zest, Cardamom       NaN
# 20       Floral Honey, Tart Apple, Lime, Dried Cherry       NaN
# 21     Hibiscus Tea, White Grape, Dried Cherry, Silky       NaN
# 22            Red Apple, Cacao Nib, Taffy Candy, Plum       NaN
# 23           Red Apple, Milk Chocolate, Pomelo, Juicy       NaN
# 24             Apricot, Chamomile, Green Apple, Prune       NaN
# 25     Concord Grape, Caramel, Cherry, Dark Chocolate       NaN
# 26  Raspberry Lambic, Raw Honey, Mango Nectar, Cherry       NaN
# 27         Jasmine, Sweet Tea, White Grape, Blueberry       NaN
# 28            Dried Cherry, Molasses, Hibiscus, Juicy       NaN
# 29               Plum, Molasses, Spiced Cider, Raisin       NaN
# 30  Yellow Pear, Mānuka Honey, Concord Grape, Raw ...       NaN
# 31         Apple, Dark Honey, Toasted Almond, Vanilla       NaN
# 32         Apple, Dark Chocolate, Almond, Brown Sugar       NaN
# 33  Baker's Chocolate, Burnt Sugar, Smoked Vanilla...       NaN
#
#                                                  Name  \
# 0                                          Uji Matcha
# 1                                                 404
# 2                                                None
# 3   Finest coffee in the worldevery month for the ...
# 4                                    Southern Weather
# 5                                            Geometry
# 6                                             Monarch
# 7                                    Tropical Weather
# 8                                           Power Nap
# 9                                           Cold Brew
# 10                                        Silverstein
# 11                       Colombia El Vergel Java Koji
# 12                 Colombia Wilder Lasso Citric Gesha
# 13                  Burundi Long Miles Gaharo Natural
# 14                                  Kenya Gachatha AA
# 15                                   Kenya Karinga PB
# 16                         Ecuador Olger Rogel Typica
# 17                            Colombia Norby Quimbayo
# 18                       Ethiopia Guji Gigesa Natural
# 19                        Ethiopia Gedeb Banko Gotiti
# 20            Colombia Robinson Figueroa Pink Bourbon
# 21                     Colombia La Palma Hugo Hurtado
# 22                 Colombia La Palma Alvaro Rodriguez
# 23                             Colombia Edilma Loaiza
# 24                                     Decaf Geometry
# 25                       Costa Rica Las Lajas Natural
# 26             Costa Rica Las Lajas Heirloom Ethiopia
# 27                                     BIGFACE | ONYX
# 28                    Burundi Campazi Colline Natural
# 29                    Honduras Finca La Unica Natural
# 30                                 Ethiopia Gore Dako
# 31                                       Rwanda Kanzu
# 32                               Decaf Colombia Huila
# 33                                            Eclipse
#
#                                           Description             Origin:  \
# 0   This exceptional matcha powder comes from a sm...                 NaN
# 1                                                None                 NaN
# 2                                                None                 NaN
# 3                                                None                 NaN
# 4   Southern Weather embodies everything we love a...  Colombia, Ethiopia
# 5   Geometry has been defined as "describing space...  Colombia, Ethiopia
# 6   Monarch is our most developed roast that conve...                 NaN
# 7   Tropical Weather is a seasonal blend that cele...            Ethiopia
# 8   OK, so you need a quick burst of energy, but y...                 NaN
# 9   This coffee is intentionally sourced and roast...  Colombia, Ethiopia
# 10  Prepare to embark on a sensory journey that ha...                 NaN
# 11  This is the coffee that has sparked debates, n...                 NaN
# 12  This silky and refined Gesha gets its citric p...                 NaN
# 13  This natural processed coffee comes to us from...                 NaN
# 14  For the past seven years, the Gachatha washing...                 NaN
# 15  Karinga Factory, founded in 1983 and boasting ...                 NaN
# 16  Lovers of washed coffees delight, for this cof...                 NaN
# 17  Utilizing an advance processing method known a...                 NaN
# 18  This natural-processed micro-lot from Guji fal...                 NaN
# 19  Washed coffees from the Gedeb region are often...                 NaN
# 20  This micro-lot comes from Robinson Figueroa, a...                 NaN
# 21  This classic yet refined Colombian micro-lot f...                 NaN
# 22  This lactic-processed micro-lot from our frien...                 NaN
# 23  Edilma Loaiza grows coffee in the soaring heig...                 NaN
# 24  Rest easy with our newest decaf offering in th...  Colombia, Ethiopia
# 25  This naturally processed coffee has become a s...                 NaN
# 26  Ethiopia… in Costa Rica? The movement of coffe...                 NaN
# 27  It started in the NBA playoff Bubble in 2020. ...                 NaN
# 28  Grown amidst the stunning landscapes of the Ka...                 NaN
# 29  We are honored and excited to offer this beaut...                 NaN
# 30  The first arrival of the Ethiopian harvest is ...                 NaN
# 31  In the tropical volcanic soil of Rwanda just w...                 NaN
# 32  Calm down with this delicious decaf from our f...                 NaN
# 33  While most of our coffees thrive on the lighte...                 NaN
#
#      Elevation:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4          1850
# 5   1950 - 2100
# 6          1800
# 7          1900
# 8   1950 - 2000
# 9          1850
# 10         1450
# 11         1550
# 12    1900 MASL
# 13         1950
# 14    1850 MASL
# 15         1800
# 16    1650 MASL
# 17    1800 MASL
# 18         2000
# 19         2050
# 20         1750
# 21    1700 MASL
# 22    1700 MASL
# 23    2100 MASL
# 24         1950
# 25  1450 Meters
# 26         1450
# 27  1850 Meters
# 28  1950 Meters
# 29  1400 Meters
# 30  2000 Meters
# 31  1900 Meters
# 32  1950 Meters
# 33         1850

# %% [markdown]
# A couple quick things to tidy-up the table to begin:

# %%
df_coffee_info = df_coffee_info.drop([0,1,2,3], axis=0).reset_index(drop = True)
df_coffee_info = df_coffee_info.drop(['Caffeine:'], axis=1)
df_coffee_info.columns = df_coffee_info.columns.str.replace(':','')
df_coffee_info.head()
# Out:
#               Variety                   Process  \
# 0                 NaN                    Washed
# 1                 NaN                    Washed
# 2  Colombia, Ethiopia           Washed, Natural
# 3                 NaN           Natural, Washed
# 4  Colombia, Ethiopia  Washed, Raised-Bed Dreid
#
#                                                  Cup              Name  \
# 0  Milk Chocolate, Plum, Candied Walnuts, Juicy &...  Southern Weather
# 1  Berries, Stone Fruit, Earl Grey, Honeysuckle, ...          Geometry
# 2  Dark Chocolate, Molasses, Red Wine, Dried Berr...           Monarch
# 3          Mixed Berries, Sweet Tea, Raw Honey, Plum  Tropical Weather
# 4           Brown Sugar, Cocoa, Silky, Floral, Peach         Power Nap
#
#                                          Description              Origin  \
# 0  Southern Weather embodies everything we love a...  Colombia, Ethiopia
# 1  Geometry has been defined as "describing space...  Colombia, Ethiopia
# 2  Monarch is our most developed roast that conve...                 NaN
# 3  Tropical Weather is a seasonal blend that cele...            Ethiopia
# 4  OK, so you need a quick burst of energy, but y...                 NaN
#
#      Elevation
# 0         1850
# 1  1950 - 2100
# 2         1800
# 3         1900
# 4  1950 - 2000

# %% [markdown]
# Eventually, I want to gather data from various roasteries and concatenate the tables. Because of this, I need to include the roaster name: Onyx

# %%
df_coffee_info.insert(0, 'Roaster', 'Onyx')
df_coffee_info
# Out:
#    Roaster                      Variety  \
# 0     Onyx                          NaN
# 1     Onyx                          NaN
# 2     Onyx           Colombia, Ethiopia
# 3     Onyx                          NaN
# 4     Onyx           Colombia, Ethiopia
# 5     Onyx                          NaN
# 6     Onyx              Catuai, Caturra
# 7     Onyx                         Java
# 8     Onyx                        Gesha
# 9     Onyx                  Red Bourbon
# 10    Onyx               SL28, Ruiru 11
# 11    Onyx         SL28, SL34, Ruiru 11
# 12    Onyx                       Typica
# 13    Onyx                 Pink Bourbon
# 14    Onyx                     Heirloom
# 15    Onyx                     Heirloom
# 16    Onyx                 Pink Bourbon
# 17    Onyx  Caturra, Castillo, Colombia
# 18    Onyx  Caturra, Castillo, Colombia
# 19    Onyx   Bourbon, Caturra, Castillo
# 20    Onyx                          NaN
# 21    Onyx              Catuai, Caturra
# 22    Onyx            Ethiopia Heirloom
# 23    Onyx                        Gesha
# 24    Onyx                  Red Bourbon
# 25    Onyx                    Parainema
# 26    Onyx                     Heirloom
# 27    Onyx                  Red Bourbon
# 28    Onyx  Caturra, Castillo, Colombia
# 29    Onyx                    Guatemala
#
#                                       Process  \
# 0                                      Washed
# 1                                      Washed
# 2                             Washed, Natural
# 3                             Natural, Washed
# 4                    Washed, Raised-Bed Dreid
# 5                         Washed, Patio Dried
# 6                          Honey, Patio Dried
# 7   Koji Inoculated Natural, Raised Bed Dried
# 8                    Washed, Raised-Bed Dried
# 9                   Natural, Raised-Bed Dried
# 10                   Washed, Raised-Bed Dried
# 11                   Washed, Raised-Bed Dried
# 12                   Washed, Raised-Bed Dried
# 13                   Washed, Raised-Bed Dried
# 14                  Natural, Raised-Bed Dried
# 15                   Washed, Raised-Bed Dried
# 16                   Washed, Raised Bed Dried
# 17            Lactic Washed, Raised Bed Dried
# 18            Lactic Washed, Raised Bed Dried
# 19                   Washed, Raised Bed Dried
# 20   Washed Swiss-Water Decaf, Honey EA Decaf
# 21                  Natural, Raised-Bed Dried
# 22                  Natural, Raised-Bed Dried
# 23         Washed & Natural, Raised-Bed Dried
# 24                  Natural, Raised-Bed Dried
# 25                  Natural, Raised Bed Dried
# 26                   Washed, Raised Bed Dried
# 27                   Washed, Raised-Bed Dried
# 28                  Washed, EA Decaffeination
# 29                   Washed, Raised-Bed Dried
#
#                                                   Cup  \
# 0   Milk Chocolate, Plum, Candied Walnuts, Juicy &...
# 1   Berries, Stone Fruit, Earl Grey, Honeysuckle, ...
# 2   Dark Chocolate, Molasses, Red Wine, Dried Berr...
# 3           Mixed Berries, Sweet Tea, Raw Honey, Plum
# 4            Brown Sugar, Cocoa, Silky, Floral, Peach
# 5      Cocoa, Dates, Brown Sugar, Stone Fruit, Creamy
# 6            Apple Cider, Cherry, Cacao Nib, Hibiscus
# 7           Raspberry, Watermelon Candy, Winey, Mango
# 8             Lemon, Black Tea, Orange Blossom, Honey
# 9   Dried Cherry, Milk Chocolate, Nectarine, Black...
# 10           Ripe Peach, Raw Sugar, Grapefruit, Round
# 11  Ripe Nectarine, Cane Sugar, Grapefruit Oil, Hi...
# 12                          Almond, Lime, Clove, Pear
# 13              Plum, Black Tea, Blood Orange, Cherry
# 14              Plum, Vanilla Pod, Baked Apple, Round
# 15              Melon, Jasmine, Orange Zest, Cardamom
# 16       Floral Honey, Tart Apple, Lime, Dried Cherry
# 17     Hibiscus Tea, White Grape, Dried Cherry, Silky
# 18            Red Apple, Cacao Nib, Taffy Candy, Plum
# 19           Red Apple, Milk Chocolate, Pomelo, Juicy
# 20             Apricot, Chamomile, Green Apple, Prune
# 21     Concord Grape, Caramel, Cherry, Dark Chocolate
# 22  Raspberry Lambic, Raw Honey, Mango Nectar, Cherry
# 23         Jasmine, Sweet Tea, White Grape, Blueberry
# 24            Dried Cherry, Molasses, Hibiscus, Juicy
# 25               Plum, Molasses, Spiced Cider, Raisin
# 26  Yellow Pear, Mānuka Honey, Concord Grape, Raw ...
# 27         Apple, Dark Honey, Toasted Almond, Vanilla
# 28         Apple, Dark Chocolate, Almond, Brown Sugar
# 29  Baker's Chocolate, Burnt Sugar, Smoked Vanilla...
#
#                                        Name  \
# 0                          Southern Weather
# 1                                  Geometry
# 2                                   Monarch
# 3                          Tropical Weather
# 4                                 Power Nap
# 5                                 Cold Brew
# 6                               Silverstein
# 7              Colombia El Vergel Java Koji
# 8        Colombia Wilder Lasso Citric Gesha
# 9         Burundi Long Miles Gaharo Natural
# 10                        Kenya Gachatha AA
# 11                         Kenya Karinga PB
# 12               Ecuador Olger Rogel Typica
# 13                  Colombia Norby Quimbayo
# 14             Ethiopia Guji Gigesa Natural
# 15              Ethiopia Gedeb Banko Gotiti
# 16  Colombia Robinson Figueroa Pink Bourbon
# 17           Colombia La Palma Hugo Hurtado
# 18       Colombia La Palma Alvaro Rodriguez
# 19                   Colombia Edilma Loaiza
# 20                           Decaf Geometry
# 21             Costa Rica Las Lajas Natural
# 22   Costa Rica Las Lajas Heirloom Ethiopia
# 23                           BIGFACE | ONYX
# 24          Burundi Campazi Colline Natural
# 25          Honduras Finca La Unica Natural
# 26                       Ethiopia Gore Dako
# 27                             Rwanda Kanzu
# 28                     Decaf Colombia Huila
# 29                                  Eclipse
#
#                                           Description              Origin  \
# 0   Southern Weather embodies everything we love a...  Colombia, Ethiopia
# 1   Geometry has been defined as "describing space...  Colombia, Ethiopia
# 2   Monarch is our most developed roast that conve...                 NaN
# 3   Tropical Weather is a seasonal blend that cele...            Ethiopia
# 4   OK, so you need a quick burst of energy, but y...                 NaN
# 5   This coffee is intentionally sourced and roast...  Colombia, Ethiopia
# 6   Prepare to embark on a sensory journey that ha...                 NaN
# 7   This is the coffee that has sparked debates, n...                 NaN
# 8   This silky and refined Gesha gets its citric p...                 NaN
# 9   This natural processed coffee comes to us from...                 NaN
# 10  For the past seven years, the Gachatha washing...                 NaN
# 11  Karinga Factory, founded in 1983 and boasting ...                 NaN
# 12  Lovers of washed coffees delight, for this cof...                 NaN
# 13  Utilizing an advance processing method known a...                 NaN
# 14  This natural-processed micro-lot from Guji fal...                 NaN
# 15  Washed coffees from the Gedeb region are often...                 NaN
# 16  This micro-lot comes from Robinson Figueroa, a...                 NaN
# 17  This classic yet refined Colombian micro-lot f...                 NaN
# 18  This lactic-processed micro-lot from our frien...                 NaN
# 19  Edilma Loaiza grows coffee in the soaring heig...                 NaN
# 20  Rest easy with our newest decaf offering in th...  Colombia, Ethiopia
# 21  This naturally processed coffee has become a s...                 NaN
# 22  Ethiopia… in Costa Rica? The movement of coffe...                 NaN
# 23  It started in the NBA playoff Bubble in 2020. ...                 NaN
# 24  Grown amidst the stunning landscapes of the Ka...                 NaN
# 25  We are honored and excited to offer this beaut...                 NaN
# 26  The first arrival of the Ethiopian harvest is ...                 NaN
# 27  In the tropical volcanic soil of Rwanda just w...                 NaN
# 28  Calm down with this delicious decaf from our f...                 NaN
# 29  While most of our coffees thrive on the lighte...                 NaN
#
#       Elevation
# 0          1850
# 1   1950 - 2100
# 2          1800
# 3          1900
# 4   1950 - 2000
# 5          1850
# 6          1450
# 7          1550
# 8     1900 MASL
# 9          1950
# 10    1850 MASL
# 11         1800
# 12    1650 MASL
# 13    1800 MASL
# 14         2000
# 15         2050
# 16         1750
# 17    1700 MASL
# 18    1700 MASL
# 19    2100 MASL
# 20         1950
# 21  1450 Meters
# 22         1450
# 23  1850 Meters
# 24  1950 Meters
# 25  1400 Meters
# 26  2000 Meters
# 27  1900 Meters
# 28  1950 Meters
# 29         1850

# %%
df_coffee_info.groupby('Elevation').agg({'Process':'unique', 'Variety':'unique'})
# Out:
#                                                        Process  \
# Elevation
# 1400 Meters                        [Natural, Raised Bed Dried]
# 1450           [Honey, Patio Dried, Natural, Raised-Bed Dried]
# 1450 Meters                        [Natural, Raised-Bed Dried]
# 1550               [Koji Inoculated Natural, Raised Bed Dried]
# 1650 MASL                           [Washed, Raised-Bed Dried]
# 1700 MASL                    [Lactic Washed, Raised Bed Dried]
# 1750                                [Washed, Raised Bed Dried]
# 1800               [Washed, Natural, Washed, Raised-Bed Dried]
# 1800 MASL                           [Washed, Raised-Bed Dried]
# 1850         [Washed, Washed, Patio Dried, Washed, Raised-B...
# 1850 MASL                           [Washed, Raised-Bed Dried]
# 1850 Meters               [Washed & Natural, Raised-Bed Dried]
# 1900                                         [Natural, Washed]
# 1900 MASL                           [Washed, Raised-Bed Dried]
# 1900 Meters                         [Washed, Raised-Bed Dried]
# 1950         [Natural, Raised-Bed Dried, Washed Swiss-Water...
# 1950 - 2000                         [Washed, Raised-Bed Dreid]
# 1950 - 2100                                           [Washed]
# 1950 Meters  [Natural, Raised-Bed Dried, Washed, EA Decaffe...
# 2000                               [Natural, Raised-Bed Dried]
# 2000 Meters                         [Washed, Raised Bed Dried]
# 2050                                [Washed, Raised-Bed Dried]
# 2100 MASL                           [Washed, Raised Bed Dried]
#
#                                                 Variety
# Elevation
# 1400 Meters                                 [Parainema]
# 1450               [Catuai, Caturra, Ethiopia Heirloom]
# 1450 Meters                           [Catuai, Caturra]
# 1550                                             [Java]
# 1650 MASL                                      [Typica]
# 1700 MASL                 [Caturra, Castillo, Colombia]
# 1750                                     [Pink Bourbon]
# 1800         [Colombia, Ethiopia, SL28, SL34, Ruiru 11]
# 1800 MASL                                [Pink Bourbon]
# 1850                                   [nan, Guatemala]
# 1850 MASL                              [SL28, Ruiru 11]
# 1850 Meters                                     [Gesha]
# 1900                                              [nan]
# 1900 MASL                                       [Gesha]
# 1900 Meters                               [Red Bourbon]
# 1950                                 [Red Bourbon, nan]
# 1950 - 2000                        [Colombia, Ethiopia]
# 1950 - 2100                                       [nan]
# 1950 Meters  [Red Bourbon, Caturra, Castillo, Colombia]
# 2000                                         [Heirloom]
# 2000 Meters                                  [Heirloom]
# 2050                                         [Heirloom]
# 2100 MASL                  [Bourbon, Caturra, Castillo]
