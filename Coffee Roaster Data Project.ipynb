# %% [markdown]
# # Coffee Availability By Roaster - Web Scraping Project
# ## Using BeautifulSoup to gather information about coffees for sale from select roasters
#
# The goal of this project is to create a DataFrame with information compiled from selected Coffee Roaster websites in the U.S., with the goal of being able to compare and contrast the available options.
#
# Once the following info is in a pandas DataFrame, it will be possible to search and filter coffees based on preferred origin, price, etc.
#
#  - Information I hope to include:
#      + Roaster Name
#      + Coffee Name
#      + Country/Countries of Origin
#      + Description
#      + Tasting Notes
#      + Variety
#      + Process
#      + Size Options
#      + Avg Price Per Pound or Ounce

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import csv

# %%
onyx_url = 'https://onyxcoffeelab.com/collections/coffee'
equator_url = 'https://www.equatorcoffees.com/collections/coffees'
ruby_url = 'https://rubycoffeeroasters.com/collections/coffee'

# %%
def gather_coffee_links(url):
    r= requests.get(url)
    soup = BeautifulSoup(r.content, 'html.parser')
    coffee_links = soup.find_all('a')
    
    links = []
    for link in coffee_links:
        links.append(url+link["href"])

    coffee_link_list = []
    for link in links:
        if '/product' in link:
            coffee_link_list.append(link)

    return coffee_link_list

# %%
def get_coffee_attrs(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')
    coffee_data = {}
    try:
        name = soup.find('h1').text.strip()
    except:
        name = None
    try:
        coffee_description = soup.find('div', {'class':'main-blurb'}).getText().strip()
    except:
        coffee_description = None
    for div in soup.find_all('div', {'class':'a-feature'}):
        try:
            label = div.find('div', {'class':'label'})
            label_value = div.find('div', {'class':'value'})
            coffee_data[label.text]=label_value.text
        except:
            label = None
            label_value = None
    coffee_data.update({'Name':name, 'Description':coffee_description})
    return coffee_data

# %%
coffee_data = []
for link in onyx_links:
    coffee_data.append(get_coffee_attrs(link))

# %%
df_coffee_info = pd.DataFrame(coffee_data)
df_coffee_info.head(25)
# Out:
#                                                  Name  \
# 0                                                 404
# 1   Finest coffee in the worldevery month for the ...
# 2                                                None
# 3                                    Southern Weather
# 4                                            Geometry
# 5                                             Monarch
# 6                                    Tropical Weather
# 7                                           Power Nap
# 8                                           Cold Brew
# 9                                         Silverstein
# 10                       Colombia El Vergel Java Koji
# 11                 Colombia Wilder Lasso Citric Gesha
# 12                  Burundi Long Miles Gaharo Natural
# 13                                  Kenya Gachatha AA
# 14                                   Kenya Karinga PB
# 15                         Ecuador Olger Rogel Typica
# 16                            Colombia Norby Quimbayo
# 17                       Ethiopia Guji Gigesa Natural
# 18                        Ethiopia Gedeb Banko Gotiti
# 19            Colombia Robinson Figueroa Pink Bourbon
# 20                     Colombia La Palma Hugo Hurtado
# 21                 Colombia La Palma Alvaro Rodriguez
# 22                             Colombia Edilma Loaiza
# 23                                     Decaf Geometry
# 24                       Costa Rica Las Lajas Natural
#
#                                           Description             Origin:  \
# 0                                                None                 NaN
# 1                                                None                 NaN
# 2                                                None                 NaN
# 3   Southern Weather embodies everything we love a...  Colombia, Ethiopia
# 4   Geometry has been defined as "describing space...  Colombia, Ethiopia
# 5   Monarch is our most developed roast that conve...                 NaN
# 6   Tropical Weather is a seasonal blend that cele...            Ethiopia
# 7   OK, so you need a quick burst of energy, but y...                 NaN
# 8   This coffee is intentionally sourced and roast...  Colombia, Ethiopia
# 9   Prepare to embark on a sensory journey that ha...                 NaN
# 10  This is the coffee that has sparked debates, n...                 NaN
# 11  This silky and refined Gesha gets its citric p...                 NaN
# 12  This natural processed coffee comes to us from...                 NaN
# 13  For the past seven years, the Gachatha washing...                 NaN
# 14  Karinga Factory, founded in 1983 and boasting ...                 NaN
# 15  Lovers of washed coffees delight, for this cof...                 NaN
# 16  Utilizing an advance processing method known a...                 NaN
# 17  This natural-processed micro-lot from Guji fal...                 NaN
# 18  Washed coffees from the Gedeb region are often...                 NaN
# 19  This micro-lot comes from Robinson Figueroa, a...                 NaN
# 20  This classic yet refined Colombian micro-lot f...                 NaN
# 21  This lactic-processed micro-lot from our frien...                 NaN
# 22  Edilma Loaiza grows coffee in the soaring heig...                 NaN
# 23  Rest easy with our newest decaf offering in th...  Colombia, Ethiopia
# 24  This naturally processed coffee has become a s...                 NaN
#
#                                      Process:   Elevation:  \
# 0                                         NaN          NaN
# 1                                         NaN          NaN
# 2                                         NaN          NaN
# 3                                      Washed         1850
# 4                                      Washed  1950 - 2100
# 5                             Washed, Natural         1800
# 6                             Natural, Washed         1900
# 7                    Washed, Raised-Bed Dreid  1950 - 2000
# 8                         Washed, Patio Dried         1850
# 9                          Honey, Patio Dried         1450
# 10  Koji Inoculated Natural, Raised Bed Dried         1550
# 11                   Washed, Raised-Bed Dried    1900 MASL
# 12                  Natural, Raised-Bed Dried         1950
# 13                   Washed, Raised-Bed Dried    1850 MASL
# 14                   Washed, Raised-Bed Dried         1800
# 15                   Washed, Raised-Bed Dried    1650 MASL
# 16                   Washed, Raised-Bed Dried    1800 MASL
# 17                  Natural, Raised-Bed Dried         2000
# 18                   Washed, Raised-Bed Dried         2050
# 19                   Washed, Raised Bed Dried         1750
# 20            Lactic Washed, Raised Bed Dried    1700 MASL
# 21            Lactic Washed, Raised Bed Dried    1700 MASL
# 22                   Washed, Raised Bed Dried    2100 MASL
# 23   Washed Swiss-Water Decaf, Honey EA Decaf         1950
# 24                  Natural, Raised-Bed Dried  1450 Meters
#
#                                                  Cup:  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   Milk Chocolate, Plum, Candied Walnuts, Juicy &...
# 4   Berries, Stone Fruit, Earl Grey, Honeysuckle, ...
# 5   Dark Chocolate, Molasses, Red Wine, Dried Berr...
# 6           Mixed Berries, Sweet Tea, Raw Honey, Plum
# 7            Brown Sugar, Cocoa, Silky, Floral, Peach
# 8      Cocoa, Dates, Brown Sugar, Stone Fruit, Creamy
# 9            Apple Cider, Cherry, Cacao Nib, Hibiscus
# 10          Raspberry, Watermelon Candy, Winey, Mango
# 11            Lemon, Black Tea, Orange Blossom, Honey
# 12  Dried Cherry, Milk Chocolate, Nectarine, Black...
# 13           Ripe Peach, Raw Sugar, Grapefruit, Round
# 14  Ripe Nectarine, Cane Sugar, Grapefruit Oil, Hi...
# 15                          Almond, Lime, Clove, Pear
# 16              Plum, Black Tea, Blood Orange, Cherry
# 17              Plum, Vanilla Pod, Baked Apple, Round
# 18              Melon, Jasmine, Orange Zest, Cardamom
# 19       Floral Honey, Tart Apple, Lime, Dried Cherry
# 20     Hibiscus Tea, White Grape, Dried Cherry, Silky
# 21            Red Apple, Cacao Nib, Taffy Candy, Plum
# 22           Red Apple, Milk Chocolate, Pomelo, Juicy
# 23             Apricot, Chamomile, Green Apple, Prune
# 24     Concord Grape, Caramel, Cherry, Dark Chocolate
#
#                        Variety:
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5            Colombia, Ethiopia
# 6                           NaN
# 7            Colombia, Ethiopia
# 8                           NaN
# 9               Catuai, Caturra
# 10                         Java
# 11                        Gesha
# 12                  Red Bourbon
# 13               SL28, Ruiru 11
# 14         SL28, SL34, Ruiru 11
# 15                       Typica
# 16                 Pink Bourbon
# 17                     Heirloom
# 18                     Heirloom
# 19                 Pink Bourbon
# 20  Caturra, Castillo, Colombia
# 21  Caturra, Castillo, Colombia
# 22   Bourbon, Caturra, Castillo
# 23                          NaN
# 24              Catuai, Caturra

# %%
df_coffee_info = df_coffee_info.drop([0,1,2], axis=0).reset_index(drop = True)
df_coffee_info
# Out:
#                                        Name  \
# 0                          Southern Weather
# 1                                  Geometry
# 2                                   Monarch
# 3                          Tropical Weather
# 4                                 Power Nap
# 5                                 Cold Brew
# 6                               Silverstein
# 7              Colombia El Vergel Java Koji
# 8        Colombia Wilder Lasso Citric Gesha
# 9         Burundi Long Miles Gaharo Natural
# 10                        Kenya Gachatha AA
# 11                         Kenya Karinga PB
# 12               Ecuador Olger Rogel Typica
# 13                  Colombia Norby Quimbayo
# 14             Ethiopia Guji Gigesa Natural
# 15              Ethiopia Gedeb Banko Gotiti
# 16  Colombia Robinson Figueroa Pink Bourbon
# 17           Colombia La Palma Hugo Hurtado
# 18       Colombia La Palma Alvaro Rodriguez
# 19                   Colombia Edilma Loaiza
# 20                           Decaf Geometry
# 21             Costa Rica Las Lajas Natural
# 22   Costa Rica Las Lajas Heirloom Ethiopia
# 23                           BIGFACE | ONYX
# 24          Burundi Campazi Colline Natural
# 25          Honduras Finca La Unica Natural
# 26                       Ethiopia Gore Dako
# 27                             Rwanda Kanzu
# 28                     Decaf Colombia Huila
# 29                                  Eclipse
#
#                                           Description             Origin:  \
# 0   Southern Weather embodies everything we love a...  Colombia, Ethiopia
# 1   Geometry has been defined as "describing space...  Colombia, Ethiopia
# 2   Monarch is our most developed roast that conve...                 NaN
# 3   Tropical Weather is a seasonal blend that cele...            Ethiopia
# 4   OK, so you need a quick burst of energy, but y...                 NaN
# 5   This coffee is intentionally sourced and roast...  Colombia, Ethiopia
# 6   Prepare to embark on a sensory journey that ha...                 NaN
# 7   This is the coffee that has sparked debates, n...                 NaN
# 8   This silky and refined Gesha gets its citric p...                 NaN
# 9   This natural processed coffee comes to us from...                 NaN
# 10  For the past seven years, the Gachatha washing...                 NaN
# 11  Karinga Factory, founded in 1983 and boasting ...                 NaN
# 12  Lovers of washed coffees delight, for this cof...                 NaN
# 13  Utilizing an advance processing method known a...                 NaN
# 14  This natural-processed micro-lot from Guji fal...                 NaN
# 15  Washed coffees from the Gedeb region are often...                 NaN
# 16  This micro-lot comes from Robinson Figueroa, a...                 NaN
# 17  This classic yet refined Colombian micro-lot f...                 NaN
# 18  This lactic-processed micro-lot from our frien...                 NaN
# 19  Edilma Loaiza grows coffee in the soaring heig...                 NaN
# 20  Rest easy with our newest decaf offering in th...  Colombia, Ethiopia
# 21  This naturally processed coffee has become a s...                 NaN
# 22  Ethiopia… in Costa Rica? The movement of coffe...                 NaN
# 23  It started in the NBA playoff Bubble in 2020. ...                 NaN
# 24  Grown amidst the stunning landscapes of the Ka...                 NaN
# 25  We are honored and excited to offer this beaut...                 NaN
# 26  The first arrival of the Ethiopian harvest is ...                 NaN
# 27  In the tropical volcanic soil of Rwanda just w...                 NaN
# 28  Calm down with this delicious decaf from our f...                 NaN
# 29  While most of our coffees thrive on the lighte...                 NaN
#
#                                      Process:   Elevation:  \
# 0                                      Washed         1850
# 1                                      Washed  1950 - 2100
# 2                             Washed, Natural         1800
# 3                             Natural, Washed         1900
# 4                    Washed, Raised-Bed Dreid  1950 - 2000
# 5                         Washed, Patio Dried         1850
# 6                          Honey, Patio Dried         1450
# 7   Koji Inoculated Natural, Raised Bed Dried         1550
# 8                    Washed, Raised-Bed Dried    1900 MASL
# 9                   Natural, Raised-Bed Dried         1950
# 10                   Washed, Raised-Bed Dried    1850 MASL
# 11                   Washed, Raised-Bed Dried         1800
# 12                   Washed, Raised-Bed Dried    1650 MASL
# 13                   Washed, Raised-Bed Dried    1800 MASL
# 14                  Natural, Raised-Bed Dried         2000
# 15                   Washed, Raised-Bed Dried         2050
# 16                   Washed, Raised Bed Dried         1750
# 17            Lactic Washed, Raised Bed Dried    1700 MASL
# 18            Lactic Washed, Raised Bed Dried    1700 MASL
# 19                   Washed, Raised Bed Dried    2100 MASL
# 20   Washed Swiss-Water Decaf, Honey EA Decaf         1950
# 21                  Natural, Raised-Bed Dried  1450 Meters
# 22                  Natural, Raised-Bed Dried         1450
# 23         Washed & Natural, Raised-Bed Dried  1850 Meters
# 24                  Natural, Raised-Bed Dried  1950 Meters
# 25                  Natural, Raised Bed Dried  1400 Meters
# 26                   Washed, Raised Bed Dried  2000 Meters
# 27                   Washed, Raised-Bed Dried  1900 Meters
# 28                  Washed, EA Decaffeination  1950 Meters
# 29                   Washed, Raised-Bed Dried         1850
#
#                                                  Cup:  \
# 0   Milk Chocolate, Plum, Candied Walnuts, Juicy &...
# 1   Berries, Stone Fruit, Earl Grey, Honeysuckle, ...
# 2   Dark Chocolate, Molasses, Red Wine, Dried Berr...
# 3           Mixed Berries, Sweet Tea, Raw Honey, Plum
# 4            Brown Sugar, Cocoa, Silky, Floral, Peach
# 5      Cocoa, Dates, Brown Sugar, Stone Fruit, Creamy
# 6            Apple Cider, Cherry, Cacao Nib, Hibiscus
# 7           Raspberry, Watermelon Candy, Winey, Mango
# 8             Lemon, Black Tea, Orange Blossom, Honey
# 9   Dried Cherry, Milk Chocolate, Nectarine, Black...
# 10           Ripe Peach, Raw Sugar, Grapefruit, Round
# 11  Ripe Nectarine, Cane Sugar, Grapefruit Oil, Hi...
# 12                          Almond, Lime, Clove, Pear
# 13              Plum, Black Tea, Blood Orange, Cherry
# 14              Plum, Vanilla Pod, Baked Apple, Round
# 15              Melon, Jasmine, Orange Zest, Cardamom
# 16       Floral Honey, Tart Apple, Lime, Dried Cherry
# 17     Hibiscus Tea, White Grape, Dried Cherry, Silky
# 18            Red Apple, Cacao Nib, Taffy Candy, Plum
# 19           Red Apple, Milk Chocolate, Pomelo, Juicy
# 20             Apricot, Chamomile, Green Apple, Prune
# 21     Concord Grape, Caramel, Cherry, Dark Chocolate
# 22  Raspberry Lambic, Raw Honey, Mango Nectar, Cherry
# 23         Jasmine, Sweet Tea, White Grape, Blueberry
# 24            Dried Cherry, Molasses, Hibiscus, Juicy
# 25               Plum, Molasses, Spiced Cider, Raisin
# 26  Yellow Pear, Mānuka Honey, Concord Grape, Raw ...
# 27         Apple, Dark Honey, Toasted Almond, Vanilla
# 28         Apple, Dark Chocolate, Almond, Brown Sugar
# 29  Baker's Chocolate, Burnt Sugar, Smoked Vanilla...
#
#                        Variety:
# 0                           NaN
# 1                           NaN
# 2            Colombia, Ethiopia
# 3                           NaN
# 4            Colombia, Ethiopia
# 5                           NaN
# 6               Catuai, Caturra
# 7                          Java
# 8                         Gesha
# 9                   Red Bourbon
# 10               SL28, Ruiru 11
# 11         SL28, SL34, Ruiru 11
# 12                       Typica
# 13                 Pink Bourbon
# 14                     Heirloom
# 15                     Heirloom
# 16                 Pink Bourbon
# 17  Caturra, Castillo, Colombia
# 18  Caturra, Castillo, Colombia
# 19   Bourbon, Caturra, Castillo
# 20                          NaN
# 21              Catuai, Caturra
# 22            Ethiopia Heirloom
# 23                        Gesha
# 24                  Red Bourbon
# 25                    Parainema
# 26                     Heirloom
# 27                  Red Bourbon
# 28  Caturra, Castillo, Colombia
# 29                    Guatemala

# %%
df_coffee_info.insert(0, 'Roaster', 'Onyx')
df_coffee_info
# Out:
#    Roaster                                     Name  \
# 0     Onyx                         Southern Weather
# 1     Onyx                                 Geometry
# 2     Onyx                                  Monarch
# 3     Onyx                         Tropical Weather
# 4     Onyx                                Power Nap
# 5     Onyx                                Cold Brew
# 6     Onyx                              Silverstein
# 7     Onyx             Colombia El Vergel Java Koji
# 8     Onyx       Colombia Wilder Lasso Citric Gesha
# 9     Onyx        Burundi Long Miles Gaharo Natural
# 10    Onyx                        Kenya Gachatha AA
# 11    Onyx                         Kenya Karinga PB
# 12    Onyx               Ecuador Olger Rogel Typica
# 13    Onyx                  Colombia Norby Quimbayo
# 14    Onyx             Ethiopia Guji Gigesa Natural
# 15    Onyx              Ethiopia Gedeb Banko Gotiti
# 16    Onyx  Colombia Robinson Figueroa Pink Bourbon
# 17    Onyx           Colombia La Palma Hugo Hurtado
# 18    Onyx       Colombia La Palma Alvaro Rodriguez
# 19    Onyx                   Colombia Edilma Loaiza
# 20    Onyx                           Decaf Geometry
# 21    Onyx             Costa Rica Las Lajas Natural
# 22    Onyx   Costa Rica Las Lajas Heirloom Ethiopia
# 23    Onyx                           BIGFACE | ONYX
# 24    Onyx          Burundi Campazi Colline Natural
# 25    Onyx          Honduras Finca La Unica Natural
# 26    Onyx                       Ethiopia Gore Dako
# 27    Onyx                             Rwanda Kanzu
# 28    Onyx                     Decaf Colombia Huila
# 29    Onyx                                  Eclipse
#
#                                           Description             Origin:  \
# 0   Southern Weather embodies everything we love a...  Colombia, Ethiopia
# 1   Geometry has been defined as "describing space...  Colombia, Ethiopia
# 2   Monarch is our most developed roast that conve...                 NaN
# 3   Tropical Weather is a seasonal blend that cele...            Ethiopia
# 4   OK, so you need a quick burst of energy, but y...                 NaN
# 5   This coffee is intentionally sourced and roast...  Colombia, Ethiopia
# 6   Prepare to embark on a sensory journey that ha...                 NaN
# 7   This is the coffee that has sparked debates, n...                 NaN
# 8   This silky and refined Gesha gets its citric p...                 NaN
# 9   This natural processed coffee comes to us from...                 NaN
# 10  For the past seven years, the Gachatha washing...                 NaN
# 11  Karinga Factory, founded in 1983 and boasting ...                 NaN
# 12  Lovers of washed coffees delight, for this cof...                 NaN
# 13  Utilizing an advance processing method known a...                 NaN
# 14  This natural-processed micro-lot from Guji fal...                 NaN
# 15  Washed coffees from the Gedeb region are often...                 NaN
# 16  This micro-lot comes from Robinson Figueroa, a...                 NaN
# 17  This classic yet refined Colombian micro-lot f...                 NaN
# 18  This lactic-processed micro-lot from our frien...                 NaN
# 19  Edilma Loaiza grows coffee in the soaring heig...                 NaN
# 20  Rest easy with our newest decaf offering in th...  Colombia, Ethiopia
# 21  This naturally processed coffee has become a s...                 NaN
# 22  Ethiopia… in Costa Rica? The movement of coffe...                 NaN
# 23  It started in the NBA playoff Bubble in 2020. ...                 NaN
# 24  Grown amidst the stunning landscapes of the Ka...                 NaN
# 25  We are honored and excited to offer this beaut...                 NaN
# 26  The first arrival of the Ethiopian harvest is ...                 NaN
# 27  In the tropical volcanic soil of Rwanda just w...                 NaN
# 28  Calm down with this delicious decaf from our f...                 NaN
# 29  While most of our coffees thrive on the lighte...                 NaN
#
#                                      Process:   Elevation:  \
# 0                                      Washed         1850
# 1                                      Washed  1950 - 2100
# 2                             Washed, Natural         1800
# 3                             Natural, Washed         1900
# 4                    Washed, Raised-Bed Dreid  1950 - 2000
# 5                         Washed, Patio Dried         1850
# 6                          Honey, Patio Dried         1450
# 7   Koji Inoculated Natural, Raised Bed Dried         1550
# 8                    Washed, Raised-Bed Dried    1900 MASL
# 9                   Natural, Raised-Bed Dried         1950
# 10                   Washed, Raised-Bed Dried    1850 MASL
# 11                   Washed, Raised-Bed Dried         1800
# 12                   Washed, Raised-Bed Dried    1650 MASL
# 13                   Washed, Raised-Bed Dried    1800 MASL
# 14                  Natural, Raised-Bed Dried         2000
# 15                   Washed, Raised-Bed Dried         2050
# 16                   Washed, Raised Bed Dried         1750
# 17            Lactic Washed, Raised Bed Dried    1700 MASL
# 18            Lactic Washed, Raised Bed Dried    1700 MASL
# 19                   Washed, Raised Bed Dried    2100 MASL
# 20   Washed Swiss-Water Decaf, Honey EA Decaf         1950
# 21                  Natural, Raised-Bed Dried  1450 Meters
# 22                  Natural, Raised-Bed Dried         1450
# 23         Washed & Natural, Raised-Bed Dried  1850 Meters
# 24                  Natural, Raised-Bed Dried  1950 Meters
# 25                  Natural, Raised Bed Dried  1400 Meters
# 26                   Washed, Raised Bed Dried  2000 Meters
# 27                   Washed, Raised-Bed Dried  1900 Meters
# 28                  Washed, EA Decaffeination  1950 Meters
# 29                   Washed, Raised-Bed Dried         1850
#
#                                                  Cup:  \
# 0   Milk Chocolate, Plum, Candied Walnuts, Juicy &...
# 1   Berries, Stone Fruit, Earl Grey, Honeysuckle, ...
# 2   Dark Chocolate, Molasses, Red Wine, Dried Berr...
# 3           Mixed Berries, Sweet Tea, Raw Honey, Plum
# 4            Brown Sugar, Cocoa, Silky, Floral, Peach
# 5      Cocoa, Dates, Brown Sugar, Stone Fruit, Creamy
# 6            Apple Cider, Cherry, Cacao Nib, Hibiscus
# 7           Raspberry, Watermelon Candy, Winey, Mango
# 8             Lemon, Black Tea, Orange Blossom, Honey
# 9   Dried Cherry, Milk Chocolate, Nectarine, Black...
# 10           Ripe Peach, Raw Sugar, Grapefruit, Round
# 11  Ripe Nectarine, Cane Sugar, Grapefruit Oil, Hi...
# 12                          Almond, Lime, Clove, Pear
# 13              Plum, Black Tea, Blood Orange, Cherry
# 14              Plum, Vanilla Pod, Baked Apple, Round
# 15              Melon, Jasmine, Orange Zest, Cardamom
# 16       Floral Honey, Tart Apple, Lime, Dried Cherry
# 17     Hibiscus Tea, White Grape, Dried Cherry, Silky
# 18            Red Apple, Cacao Nib, Taffy Candy, Plum
# 19           Red Apple, Milk Chocolate, Pomelo, Juicy
# 20             Apricot, Chamomile, Green Apple, Prune
# 21     Concord Grape, Caramel, Cherry, Dark Chocolate
# 22  Raspberry Lambic, Raw Honey, Mango Nectar, Cherry
# 23         Jasmine, Sweet Tea, White Grape, Blueberry
# 24            Dried Cherry, Molasses, Hibiscus, Juicy
# 25               Plum, Molasses, Spiced Cider, Raisin
# 26  Yellow Pear, Mānuka Honey, Concord Grape, Raw ...
# 27         Apple, Dark Honey, Toasted Almond, Vanilla
# 28         Apple, Dark Chocolate, Almond, Brown Sugar
# 29  Baker's Chocolate, Burnt Sugar, Smoked Vanilla...
#
#                        Variety:
# 0                           NaN
# 1                           NaN
# 2            Colombia, Ethiopia
# 3                           NaN
# 4            Colombia, Ethiopia
# 5                           NaN
# 6               Catuai, Caturra
# 7                          Java
# 8                         Gesha
# 9                   Red Bourbon
# 10               SL28, Ruiru 11
# 11         SL28, SL34, Ruiru 11
# 12                       Typica
# 13                 Pink Bourbon
# 14                     Heirloom
# 15                     Heirloom
# 16                 Pink Bourbon
# 17  Caturra, Castillo, Colombia
# 18  Caturra, Castillo, Colombia
# 19   Bourbon, Caturra, Castillo
# 20                          NaN
# 21              Catuai, Caturra
# 22            Ethiopia Heirloom
# 23                        Gesha
# 24                  Red Bourbon
# 25                    Parainema
# 26                     Heirloom
# 27                  Red Bourbon
# 28  Caturra, Castillo, Colombia
# 29                    Guatemala
